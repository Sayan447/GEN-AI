# %% [markdown]
# ## Streamlit is open source python library used to build beautiful, interactive web application for data science and machine learning with minimal effort

# %% [markdown]
# ## why to use streamlit
# ## easy to use
# ## fast devlopment
# ## Interractive UI element ---> buttons, sliders, text inputs, charts
# ## Great for data science --> supports pandas, matplotlib , plotly and other libraries
# ## deployment is easy
