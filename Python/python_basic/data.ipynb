# %% [markdown]
# ## data types are classification of the data that says the computer or interpreter what kind of values we can store into a variable and how much amount of memory will be consumed to store the data and the opearations it can perform

# %%
age = input("enter the input:- ")

# %%
age
# Out:
# '79'

# %%
print(age)
# Out:
# 79

# %%
print( 5 + 2)
# Out:
# 7

# %%
a = 3
b = 6
a<=b
# Out:
# True
