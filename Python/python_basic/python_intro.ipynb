# %% [markdown]
# # What is Python Language

# %% [markdown]
# ## python is type of programming language which we  can use for communicate with computer and technology

# %% [markdown]
# ## Semantics of Python Language

# %% [markdown]
# ## Semantics of python language refers to the meaning or interpretating of symbols , characters and commands in a language . It is about what the code is supposed to do when it running

# %%
name = "Amit"
Name = "Amit"
name == Name
# Out:
# True

# %%
name = "Amit"
Name = "amit"
name == Name
# Out:
# False
