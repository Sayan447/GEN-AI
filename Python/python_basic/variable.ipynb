# %% [markdown]
# ## variable as per its name, data can vary that we are going to store into it and once we have declared a variable we can vary the value stored in it

# %%
age = 23
Name = "amit"
Height = 5.8
is_true = True

# %%
age
# Out:
# 23

# %%
Name
# Out:
# 'amit'

# %%
print(Name)
# Out:
# amit

# %%
Height
# Out:
# 5.8

# %% [markdown]
# ## print() --> print function is being used to represent the value that we are going to pass inside it

# %% [markdown]
# # Comment
# ## comment is the statement in a program that we don't want the interpreter to execute
#
# ## interpreter --> executes the code line by line in python language
# ## compiler --> executes the code completely
