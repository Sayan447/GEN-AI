# %% [markdown]
# # Module and Package

# %%
def addition(num1,num2):
    return num1 + num2
print(addition(4,5))
# Out:
# 9

# %% [markdown]
# ## i want to use this logic of the function in this file into the other files

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
## How complex the logic of a square root function is going to be

# %% [markdown]
# # Module

# %% [markdown]
# ## A module in python is simply a file containing python code(functions, classes or variables) that can be imported and used in other programs

# %% [markdown]
#
# # Numpy ---> Numpy is going to help us out with applying scientific calculation on the array and we can store our data by consuming less space and we can apply the operations with our array a bit more faster as compare to those of the list
#
# ### --> We can do it in Numpy just because Numpy is having the collection of functions and attributes which can help us to efficiently  with the array

# %% [markdown]
# # Pandas
# #### Pandas we can use when we are going to work with the dataset for cleaning, pre-processing, EDA , analysis with plotting as well

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# # A module
# ## 1. A module helps in code organization
# ## 2. It promotes reusability
# ## 3. It keeps the code clean and manageable

# %%
print(cos(90))
# Out:
# -0.4480736161291701

# %%
print(factorial(5))
# Out:
# 120

# %%
math.factorial(15)
# Out:
# 1307674368000

# %%
import numpy
list_item = [[1,2,3,4,5]]
list_array = numpy.array(list_item)
type(list_array)
print(list_array)
# Out:
# [[1 2 3 4 5]]

# %%
print(type(list_array))
# Out:
# <class 'numpy.ndarray'>

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.1 MB 11.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.1 MB 8.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 7.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 7.1 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 6.0 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------- ----------------- 1.3/2.3 MB 7.2 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 4.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
# ...

# %% [markdown]
# ## I am trying to create my own library or module and in this library i want the function  and the attributes to be created on my own

# %%
## __init__.py is a file that has to be their inside the package folder and this __init.py
## file helps us out in defining our packages and initializing their namespace

# %%
## __init__.py file can remain empty and its completely fine but this file has to be their when we will be creating our new packages into the package folder

# %%
from package_folder.mathematics import addition

# %%
addition(4,8)
# Out:
# 12

# %%
from package_folder.mathematics import *

# %%
substraction(4,9)
# Out:
# 5
