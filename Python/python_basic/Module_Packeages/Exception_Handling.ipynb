# %% [markdown]
# # Exception handling

# %%
print('Hi please donot provide the denominator value as 0')
denominator = int(input('Hello Please Enter the denominator for division'))

result = 1 / denominator
print(result)
# Out:
# Hi please donot provide the denominator value as 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 print('Hi please donot provide the denominator value as 0')
#       2 denominator = int(input('Hello Please Enter the denominator for division'))
# ----> 4 result = 1 / denominator
#       5 print(result)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # error <-> Exception
# ## Exception handling <---> Error Handling

# %% [markdown]
# ## it's way in which if we are getting the error in programming or if the user entered input causes an error , then instead of throwing an error we can raise an exception

# %%
print('Hi please donot provide the denominator value as 0')
denominator = int(input('Hello Please Enter the denominator for division'))

if denominator==0:
    print('problem solved')
    
else:
    result = 1 / denominator
    print(result)
# Out:
# Hi please donot provide the denominator value as 0
# problem solved

# %% [markdown]
# ## Different Types of Exception:
#
# ## ZeroDivisionError ---> Dividing by zero
# ## FileNotFoundError --> file not found
# ## ValueError --> Invalid value
# ## TypeError ---> Invalid type

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
b=25
a=b

# %%
# try Except block

# %% [markdown]
# ## try: {You are trying to run the operation which might throw an error}
#
# ## result = a/b
# ## except: {You are going to represent that if the error has been thrown that should happen}
#
# ## print('The division is not valid')

# %%
try: 
    a=b
except: print('value b is not assigned')

# %%
try:
    a=b
except NameError as exception:
    print(exception)

# %%
den = int(input("Enter the output:--- "))
try :
    result = 1/den
    print(result)
except ZeroDivisionError as ex:
    print(ex)
# Out:
# division by zero

# %%
from calendar import c


b = input('Enter the denominator ')
try:
    result = 1/b
    print(result)
    a=c
except ZeroDivisionError as ex1:
    print(ex1)
except NameError as ex2:
    print(ex2)
except Exception as ex:
    print(ex)
# Out:
# unsupported operand type(s) for /: 'int' and 'str'

# %% [markdown]
# ## If we are getting an error and we are not aware that which specific error type it is then we can use the primary exception class which is exception

# %% [markdown]
# ## if try---> code is thrwoing an error -->except---> code will be running
# ## if try---> code is not thrwoing an error --> else---> code will be running

# %%
num = int(input('Enter the denominator '))

try: 
    result = 1/num
except Exception as ex:
    print(ex)
else: 
    print('the division result for your denominator', result)
# Out:
# the division result for your denominator 0.5

# %%
try:
    den = int(input('Enter the denominator '))
    result = 1/den

    a=b
    den2 = input('Enter the  second denominator ')
    result2 = 1/den2

except ZeroDivisionError as ex1:
    print(ex2)


except Exception as ex:
    print(ex)
    
    
    
else: 
    print("The division of 1 with your enterned value is : ", result)    
    print("The division of 1 with your enterned value is : ", result2)    



finally:
    print('The program execution is completely done now')
# Out:
# unsupported operand type(s) for /: 'int' and 'str'
# The program execution is completely done now

# %%
## Exception ---> FileNotFoundError

try:
    f = open('example.txt', 'r')
    content = f.read()
    print(content)
    
except FileNotFoundError as ex :
    print(ex)
    
finally : 
    if 'f' in locals() and not f.closed:
        # is used to safely check whether the file exists and is still open before closing it.
        
        
        # locals() returns a dictionary of all local variables inside the current function/block.
        
        # Check if variable f exists in the current local scope
        f.close()
        print('file closed')
        
        
        
        
        
        # 'f' in locals() and not f.closed ensures that the file variable exists and is still open before attempting to close it, preventing errors if the file failed to open.
# Out:
# name,age
# sonu,25
#
# file closed
