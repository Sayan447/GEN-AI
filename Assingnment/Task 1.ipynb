# %% [markdown]
# # Task.1 Product collection (List & tuple)

# %% [markdown]
# ## create a list named products containing at least 6 product names(string)

# %%
lst = ["Laptop", "Smartphone", "Headphones", "Keyboard", "Mouse", "Smartwatch"]

print(lst)
# Out:
# ['Laptop', 'Smartphone', 'Headphones', 'Keyboard', 'Mouse', 'Smartwatch']

# %%
sample_product = (
    "Laptop", 75000, "Electronics"
    )

print(sample_product)
print(type(sample_product))
# Out:
# ('Laptop', 75000, 'Electronics')
# <class 'tuple'>

# %%
# print the 2nd and last product from the product list
print(lst[2],lst[5])
# Out:
# Headphones Smartwatch

# %%
# Append two new product names to products and then print the updated list
lst.append("tablet")
print(lst)
# Out:
# ['Laptop', 'Smartphone', 'Headphones', 'Keyboard', 'Mouse', 'Smartwatch', 'tablet', 'tablet', 'tablet']

# %%
#  convert sample_product into a list, change it's price , and convert it back to a tuple





sample_product1 = list(sample_product)
print(sample_product1)
# Out:
# ['Laptop', 75000, 'Electronics']

# %%
print(sample_product1)

sample_product1[1] = 85000
sample_product2 = tuple(sample_product1)
print(sample_product2)
# Out:
# ['Laptop', 75000, 'Electronics']
