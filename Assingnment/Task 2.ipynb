# %% [markdown]
# # Task 2 Categories (Sets)

# %% [markdown]
# ## from your product_list, create a set of categories called categories_set.(if product names donot contain categories, create a short parallel list categories = [..] with matching length and use that.)

# %%
products = ["Laptop", "Mouse", "Keyboard", "Shirt", "Shoes", "Tablet"]
categories = ["Electronics", "Electronics", "Electronics", "Clothing", "Footwear", "Electronics"]
categories_set = set(categories)
print(categories_set)
# Out:
# {'Clothing', 'Electronics', 'Footwear'}

# %%
# Demonstrate adding a new category to the set and show that dupliactes are ignored

categories_set.add("Books")
categories_set.add("Electronics")
print(categories_set)
# Out:
# {'Books', 'Clothing', 'Electronics', 'Footwear'}

# %%
# Show how to check whether a category exists in the set (print a boolean result)
# Show how to get the total number of unique categories using a set.

# %%
print("Electronics" in categories_set)
print("Toys" in categories_set)
# Out:
# True
# False

# %%
total_categories = len(categories_set)
print(total_categories)
# Out:
# 4
