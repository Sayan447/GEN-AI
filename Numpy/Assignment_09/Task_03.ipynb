# %% [markdown]
# ## Important Numpy Mathematical Formulas

# %%
### given:
#  values = np.array([2,4,6,8,10])
# calculate:
# 1. square rot of each  element
# 2. exponential of each element
# 3. Natural logarithm of each element
# 4. sum of all elements
# 5. cumulative sum of elements
# Use Numpy function only

# %%
import numpy as np

# Given array
values = np.array([4, 6, 8, 10])

# 1. Square root of each element
sqrt_values = np.sqrt(values)

# 2. Exponential of each element
exp_values = np.exp(values)

# 3. Natural logarithm of each element
log_values = np.log(values)

# 4. Sum of all elements
sum_values = np.sum(values)

# 5. Cumulative sum of elements
cumsum_values = np.cumsum(values)

# Print results
print("Original Array:", values)
print("Square Root:", sqrt_values)
print("Exponential:", exp_values)
print("Natural Logarithm:", log_values)
print("Sum:", sum_values)
print("Cumulative Sum:", cumsum_values)
# Out:
# Original Array: [ 4  6  8 10]
# Square Root: [2.         2.44948974 2.82842712 3.16227766]
# Exponential: [   54.59815003   403.42879349  2980.95798704 22026.46579481]
# Natural Logarithm: [1.38629436 1.79175947 2.07944154 2.30258509]
# Sum: 28
# Cumulative Sum: [ 4 10 18 28]
