# %% [markdown]
# ## Inheritance (single level)

# %%
# Create a subclass ElectronicProduct that inherit from product
# Additional attribute:
# warrenty_years
# Override the get_info() method to include warrenty info.
# Create an object and demonstrate inheritance + overriding

# %%
# Create Product class
class Product:

    # Constructor
    def __init__(self, name, price, category):
        self.name = name
        self.__price = price   # Private attribute
        self.category = category

    # Getter method
    def get_price(self):
        return self.__price

    # Setter method
    def set_price(self, new_price):
        if new_price > 0:
            self.__price = new_price
            print("Price updated successfully")
        else:
            print("Price must be greater than 0")

    # Method to print product details
    def get_info(self):
        print("Product Name:", self.name)
        print("Price:", self.get_price())
        print("Category:", self.category)


# Create object
product1 = Product("Laptop", 50000, "Electronics")

# Show original details
print("Original Product Details:")
product1.get_info()

# Get price using getter
print("\nCurrent Price:", product1.get_price())

# Modify price using setter
print("\nUpdating Price...")
product1.set_price(45000)

# Check updated details
print("\nUpdated Product Details:")
product1.get_info()

# Test invalid price
print("\nTesting Invalid Price:")
product1.set_price(-1000)
# Out:
# Original Product Details:
# Product Name: Laptop
# Price: 50000
# Category: Electronics
#
# Current Price: 50000
#
# Updating Price...
# Price updated successfully
#
# Updated Product Details:
# Product Name: Laptop
# Price: 45000
# Category: Electronics
#
# Testing Invalid Price:
# Price must be greater than 0
