# %% [markdown]
# ## Introduction

# %% [markdown]
# #### Pandas is powerfull library used for data manipulation and analysis. it helps us to work with data in tabular format, just like how we deal with data and spreadsheet.

# %% [markdown]
# ### what's different kind of things that pandas provide on

# %% [markdown]
# #### pandas provides functionalities and attributes to clean, organize and analyze large amount of  data

# %% [markdown]
# ## why we should learn about it

# %% [markdown]
# #### 1. Easy to use --> works like excel inside python
# #### 2. Fast --> works like excel inside python
# #### 3. clean data --> helps clean, filter and transform messy data
# #### 4. Integrates well --> Matplotlib,Seaborn
# #### 5. Idea for ML and AI --> It is ideal for data science
